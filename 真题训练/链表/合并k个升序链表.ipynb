# %% [markdown]
# 合并 k 个有序链表
# 看下力扣第 23 题「合并K个升序链表」：
#
# 23. 合并 K 个升序链表 | 力扣 | LeetCode |  🔴
# 给你一个链表数组，每个链表都已经按升序排列。
#
# 请你将所有链表合并到一个升序链表中，返回合并后的链表。
#
# 示例 1：
#
# 输入：lists = [[1,4,5],[1,3,4],[2,6]]
# 输出：[1,1,2,3,4,4,5,6]
# 解释：链表数组如下：
# [
#   1->4->5,
#   1->3->4,
#   2->6
# ]
# 将它们合并到一个有序链表中得到。
# 1->1->2->3->4->4->5->6
# 示例 2：
#
# 输入：lists = []
# 输出：[]
# 示例 3：
#
# 输入：lists = [[]]
# 输出：[]
# 提示：
#
# k == lists.length
# 0 <= k <= 10^4
# 0 <= lists[i].length <= 500
# -10^4 <= lists[i][j] <= 10^4
# lists[i] 按 升序 排列
# lists[i].length 的总和不超过 10^4
# 题目来源：力扣 23. 合并 K 个升序链表。

# %%
import heapq

class ListNode:
    def __init__(self,val=0,next=None):
        self.val = vla
        self.next = None

class Solution:
    def mergeKLists(self,lists):
        if not lists:
            return None
        dummy = ListNode(-1)
        p = dummy
        
        pq = []

        for i, head in enumerate(lists)
            if head not None:
                heapq.heappush(pq,(head.val,i,head))
        
        while pq:
            val,i,node = heapq.heappop(pq)
            p.next = node
            heapq.heappush(pq,(p.next.val,i,p.next))
            p = p.next
        
        return dummy.next
# Out:
#   Cell In[1], line 8
#     class Solution:
#                    ^
# SyntaxError: incomplete input

# %%
import heapq

class ListNode:
    def __init__(self,x):
        self.val = x
        self.next = None

    def __lt__(self,other):
        return self.val < other.val
    
class Solution:
    def mergeKLists(self,lists):
        if not lists:
            return None
        
        dummy = ListNode(-1)
        p = dummy
        pq = []
        for i,head in enumerate(lists):
            if head:
                heapq.heappush(pq,(head,i))

        while pq:
            node,i = heapq.heappop(pq)
            p.next = node
            if node.next:
                heapq.heappush(pq,(node.next,i))
            
            p = p.next

        return dummy.next
# Out:
#   Cell In[2], line 10
#     def mergeKLists(self,lists):
#                                 ^
# SyntaxError: incomplete input

# %%
i
