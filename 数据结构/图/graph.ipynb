# %%
class vertex:
    def __init__(self,id):
        self.id = id
        self.neighbors = []

# %%
# 邻接表的空间复杂度 O(V+E)
graph: list[list[int]] = []

# 邻接矩阵的空间复杂度 O(V^2)
matrix: list[list[bool]] = []

# %%
# 加权图

class Edge:
    def __init__(self,to,weight):
        self.to=to
        self.weight=weight

graph:list[list[Edge]] = []
martrix:list[list[int]] = []
